# %% [markdown]
# <a href="https://colab.research.google.com/github/novay/amikom/blob/main/Folium_Map.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import folium
from folium.plugins import HeatMap
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/Datasets/crimes-in-boston.csv', encoding='latin-1')

df = df[pd.notnull(df['Long'])]
df = df[pd.notnull(df['Lat'])]
df['Count'] = 1

# %%
df_murder = df[df['OFFENSE_CODE_GROUP'] == 'Drug Violation']
df_murder.tail()
# Out:
#        INCIDENT_NUMBER  OFFENSE_CODE OFFENSE_CODE_GROUP  \
# 303312   I130031413-00          1866     Drug Violation
# 303330   I120201612-00          1841     Drug Violation
# 303362   I080542626-00          1848     Drug Violation
# 303363   I080542626-00          1849     Drug Violation
# 303364   I060168073-00          1864     Drug Violation
#
#                                    OFFENSE_DESCRIPTION DISTRICT  \
# 303312     DRUGS - POSS CLASS E INTENT TO MF DIST DISP       D4
# 303330  DRUGS - POSS CLASS A - INTENT TO MFR DIST DISP       B2
# 303362  DRUGS - POSS CLASS B - INTENT TO MFR DIST DISP       A1
# 303363            DRUGS - POSS CLASS B - COCAINE, ETC.       A1
# 303364     DRUGS - POSS CLASS D - INTENT MFR DIST DISP      E13
#
#        REPORTING_AREA SHOOTING     OCCURRED_ON_DATE  YEAR  MONTH DAY_OF_WEEK  \
# 303312            143      NaN  2015-12-22 21:30:00  2015     12     Tuesday
# 303330            292      NaN  2017-01-20 02:00:00  2017      1      Friday
# ...

# %%
def generateBaseMap(default_location = [df['Lat'].median(), df['Long'].median()], default_zoom_start = 12):
    base_map = folium.Map(location = default_location, control_scale = True, zoom_start = default_zoom_start)
    return base_map

base_map = generateBaseMap()

HeatMap(data = df_murder[['Lat', 'Long', 'Count']]
        .groupby(['Lat', 'Long'])
        .sum()
        .reset_index()
        .values.tolist(), radius = 8,max_zoom = 13).add_to(base_map)

base_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
